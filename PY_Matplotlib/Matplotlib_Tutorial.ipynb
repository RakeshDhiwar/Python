# %%
import matplotlib as plot

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]
plt.plot(x, y) # plot the line
plt.xlabel('x') # add x-axis label
plt.ylabel('y') # add y-axis label
plt.title('y = x^2') # add title
plt.show() # show the plot

# %%
# create a figure and an axes object
fig, ax = plt.subplots()

# plot some data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
ax.plot(x, y)

# add some labels and a title
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('A simple interactive line plot')

# show the plot
plt.show()

# %%
plt.plot([1,2,3], [4,5,8])
plt.show()

# %%
plt.plot([1,2,3], [4,5,8])
plt.title("Rk's Data")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.show()

# %%
x  = [1,2,3]
x1 = [4,5,8]
y  = [12,22,23]
y1 = [14,15,21]
plt.plot(x,y)
plt.plot(x1,y1)
plt.show()

# %%
import numpy as np
import math
x = np.arange(0,math.pi*2,0.05)
y1 = np.sin(x)
plt.plot(x,y1)
plt.show()

# %%
import numpy as np

# Generate some data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a new figure instance
fig = plt.figure()

# Add a subplot to the figure
ax = fig.add_subplot(1,1,1)

# Plot the data on the subplot
ax.plot(x, y)

# Add a title to the plot
ax.set_title('Sine Wave')

# Add labels to the x and y axes
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')

# Display the plot
plt.show()

# %%
from matplotlib import style
# style.use('ggplot')

x  = [1,2,3]
x1 = [4,5,8]
y  = [12,22,23]
y1 = [14,15,21]
plt.plot(x,y , label = 'second', linewidth=5)
plt.plot(x1,y1, label = 'firrst')
plt.legend()
plt.show()

# %%
from matplotlib import style
# style.use('ggplot')

x  = [1,2,3]
x1 = [4,5,8]
y  = [12,22,23]
y1 = [14,15,21]
plt.plot(x,y , label = 'second', linewidth=5, color='blue', linestyle='--')
plt.plot(x1,y1, label = 'firrst')
plt.legend()
plt.show()

# %%
from matplotlib import style
# style.use('ggplot')

x  = [1,2,3]
x1 = [4,5,8]
y  = [12,22,23]
y1 = [14,15,21]
plt.scatter(x,y , label = 'second', linewidth=5)
plt.plot(x1,y1, label = 'firrst')
plt.legend()
plt.show()

# %%
from matplotlib import style
# style.use('ggplot')

x  = [10,32,13]
x1 = [4,5,8]
y  = [12,42,23]
y1 = [14,15,21]
plt.hist(x, label = 'second', linewidth=5)
plt.hist(y, label = 'firrst')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(0.0, 2.0, 0.01)
s1 = np.sin(2 * np.pi * t)
s2 = np.sin(4 * np.pi * t)

# Create figure 1
plt.figure(1)
plt.subplot(211)
plt.plot(t, s1)
plt.subplot(212)
plt.plot(t, 2 * s1)

# Create figure 2
plt.figure(2)
plt.plot(t, s2)

# Switch back to figure 1 and make some changes
plt.figure(1)
plt.subplot(211)
plt.plot(t, s2, 's')
ax = plt.gca()
ax.set_xticklabels([])

plt.show()

# %%
from matplotlib import style
# style.use('ggplot')

x  = [11,21,31]
labels = ['A','B','C']
plt.pie(x, labels = labels)
plt.title("survey's data")
plt.legend()
plt.show()

# %%
from matplotlib import style
# style.use('ggplot')

x  = [1,2,3]
x1 = [4,5,8]
y  = [12,22,23]
y1 = [14,15,21]
plt.bar(x,y , label = 'second', linewidth=5, color='blue', linestyle='--')
plt.plot(x1,y1, label = 'firrst')
plt.legend()
plt.show()

# %%
from matplotlib import style
# style.use('ggplot')

x  = [1,2,3]
x1 = [4,5,8]
y  = [12,22,23]
y1 = [14,15,21]
plt.bar(x,y , label = 'second', linewidth=5, color='blue', linestyle='--')
plt.plot(x1,y1, label = 'firrst')
plt.legend()
plt.grid()
plt.show()

# %%
from matplotlib import style
#style.use('ggplot')

x  = [1,2,3]
x1 = [4,5,8]
y  = [12,22,23]
y1 = [14,15,21]
plt.plot(x,y , label = 'second', linewidth=5, color='blue', linestyle='--')
plt.plot(x1,y1, label = 'firrst')
plt.legend()
plt.show()

# %%
from matplotlib import style 
#print(plt.style.available)

x  = [1,2,3]
x1 = [4,5,8]
y  = [12,22,23]
y1 = [14,15,21]



fig,(ax1,ax2) = plt.subplots(1,2)
fig.set_facecolor("red")
ax1.set_facecolor("blue")
ax2.set_facecolor("yellow")
ax1.plot(x,y)
ax2.plot(x1,y1)
plt.style.use('grayscale') 
plt.show()

# %%
fig, axs = plt.subplots(2,2)
axs[0,0].set_facecolor("green")
axs[0,1].set_facecolor("red")
axs[1,0].set_facecolor("red")
axs[1,1].set_facecolor("green")

# %%
import matplotlib.pyplot as plt

# Creating data
year = ['2010', '2002', '2004', '2006', '2008']
production = [25, 15, 35, 30, 10]

# Plotting barchart
plt.bar(year, production)

# Saving the figure.
plt.savefig("output.jpg")

# Saving figure by changing parameter values
plt.savefig("output1", facecolor='y', bbox_inches="tight",
			pad_inches=0.3, transparent=True)
output1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 16
#      13 # Saving figure by changing parameter values
#      14 plt.savefig("output1", facecolor='y', bbox_inches="tight",
#      15 			pad_inches=0.3, transparent=True)
# ---> 16 output1
#
# NameError: name 'output1' is not defined
